# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [raw]
# Data Loading

# %%
df=pd.read_csv('Cardiotocographic.csv')
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
df.shape
# Out:
# (2126, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %% [raw]
# Data Cleaning & Preparation
# 1.Handling Missing Values

# %%
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %% [raw]
# 2.Data Type Consistency

# %%
df.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %% [raw]
# Statistical Summary
# 1 Descriptive Statistics

# %%
df.describe().T
# Out:
#           count        mean        std         min         25%         50%  \
# LB        551.0  131.359587   9.688991  106.000000  123.000000  132.000000
# AC        551.0    0.004110   0.003748   -0.000122    0.000822    0.003490
# FM        551.0    0.000006   0.000062   -0.000325    0.000000    0.000000
# UC        551.0    0.005169   0.002648   -0.000101    0.003359    0.005298
# DL        551.0    0.001199   0.001890   -0.000080    0.000000    0.000000
# DS        551.0    0.000000   0.000000    0.000000    0.000000    0.000000
# DP        551.0    0.000000   0.000000    0.000000    0.000000    0.000000
# ASTV      551.0   37.359701  13.765398   16.000000   26.000000   34.000000
# MSTV      551.0    1.237704   0.459951    0.300000    0.900000    1.200000
# ALTV      551.0    1.370628   2.666415   -0.899870    0.000000    0.000000
# MLTV      551.0    9.432558   4.225993    0.000000    6.900000    9.600000
# ...

# %%
summary = pd.DataFrame({
    "Mean": df.mean(),
    "Median": df.median(),
    "Std Dev": df.std(),
    "IQR": df.quantile(0.75) - df.quantile(0.25)
})
summary
# Out:
#                 Mean      Median    Std Dev        IQR
# LB        131.359587  132.000000   9.688991  15.000000
# AC          0.004110    0.003490   0.003748   0.005897
# FM          0.000006    0.000000   0.000062   0.000000
# UC          0.005169    0.005298   0.002648   0.003672
# DL          0.001199    0.000000   0.001890   0.001909
# DS          0.000000    0.000000   0.000000   0.000000
# DP          0.000000    0.000000   0.000000   0.000000
# ASTV       37.359701   34.000000  13.765398  23.000000
# MSTV        1.237704    1.200000   0.459951   0.600000
# ALTV        1.370628    0.000000   2.666415   1.000000
# MLTV        9.432558    9.600000   4.225993   5.275379
# Width      63.023414   56.717868  28.231026  44.157939
# Tendency    0.317550    0.000000   0.587028   1.000000
# NSP         1.000000    1.000000   0.000000   0.000000

# %% [raw]
# Data Visualization

# %% [raw]
# 1. Histograms

# %%
df.hist(figsize=(15,10), bins=20)
plt.show()

# %% [raw]
# Histograms help in understanding the distribution, spread, and skewness of each cardiographic feature.
# LB (Baseline FHR) shows a near-normal distribution,ASTV and ALTV are right-skewed,Deceleration variables (DL, DS, DP) have heavily skewed distributions

# %% [raw]
# 2.Boxplots
# Explanation:
# Boxplots provide a concise summary of median, quartiles, and outliers.

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=df)
plt.xticks(rotation=90)
plt.show()

# %% [raw]
# 3.Correlation Heatmap

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [raw]
# The heatmap visually represents the strength and direction of relationships between variables.

# %% [raw]
# 4.Pair Plot (Advanced Visualization)

# %%
sns.pairplot(df, diag_kind="kde")
plt.show()

# %% [raw]
# Pair plots allow examination of pairwise interactions and distribution shapes simultaneously.

# %% [raw]
# 5.Violin Plot

# %%
plt.figure(figsize=(8,5))
sns.violinplot(y=df["ASTV"])
plt.title("Distribution of ASTV")
plt.show()

# %% [raw]
# Violin plots combine boxplot statistics with probability density, giving a deeper understanding of data concentration.
