# %% [raw]
# Basic Stats-2

# %% [raw]
# Problem Statment: Hospital patient

# %% [raw]
# 1.	Load the patient dataset and show summary with info().

# %%
import pandas as pd
import seaborn as sns

# %%
patients=pd.read_csv('Patient_Data.csv')
patients
# Out:
#    PatientID     Name   Department     Doctor  BillAmount  ReceptionistID  \
# 0        101    Alice   Cardiology  Dr. Smith      5000.0               1
# 1        102      Bob    Neurology   Dr. John         NaN               2
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0               1
# 3        104    David   Cardiology  Dr. Smith      6200.0               3
# 4        105      Eva  Dermatology   Dr. Rose         NaN               2
# 5        101    Alice   Cardiology  Dr. Smith      5000.0               1
#
#         CheckInTime
# 0  2023-01-10 09:00
# 1  2023-01-11 10:30
# 2  2023-01-12 11:00
# 3  2023-01-13 12:00
# 4  2023-01-14 08:45
# 5  2023-01-10 09:00

# %%
patients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PatientID       6 non-null      int64
#  1   Name            6 non-null      object
#  2   Department      6 non-null      object
#  3   Doctor          6 non-null      object
#  4   BillAmount      4 non-null      float64
#  5   ReceptionistID  6 non-null      int64
#  6   CheckInTime     6 non-null      object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 468.0+ bytes

# %%
billing=pd.read_csv('Billing_Data.csv')
billing
# Out:
#    PatientID  InsuranceCovered  FinalAmount
# 0        101              2000         3000
# 1        102              1500         3500
# 2        103              2500         5000
# 3        104              3000         3200
# 4        105              1000         4000

# %%
billing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   PatientID         5 non-null      int64
#  1   InsuranceCovered  5 non-null      int64
#  2   FinalAmount       5 non-null      int64
# dtypes: int64(3)
# memory usage: 252.0 bytes

# %% [raw]
# Select only the columns relevant for billing: ['PatientID', 'Department', 'Doctor', 'BillAmount'].

# %%
selected_columns_billing=patients[['PatientID', 'Department', 'Doctor', 'BillAmount']]
selected_columns_billing
# Out:
#    PatientID   Department     Doctor  BillAmount
# 0        101   Cardiology  Dr. Smith      5000.0
# 1        102    Neurology   Dr. John         NaN
# 2        103  Orthopedics    Dr. Lee      7500.0
# 3        104   Cardiology  Dr. Smith      6200.0
# 4        105  Dermatology   Dr. Rose         NaN
# 5        101   Cardiology  Dr. Smith      5000.0

# %% [raw]
# Drop administrative columns like ['ReceptionistID', 'CheckInTime'].

# %%
patients_drop=patients.drop(columns=['ReceptionistID'])
patients_drop
# Out:
#    PatientID     Name   Department     Doctor  BillAmount       CheckInTime
# 0        101    Alice   Cardiology  Dr. Smith      5000.0  2023-01-10 09:00
# 1        102      Bob    Neurology   Dr. John         NaN  2023-01-11 10:30
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0  2023-01-12 11:00
# 3        104    David   Cardiology  Dr. Smith      6200.0  2023-01-13 12:00
# 4        105      Eva  Dermatology   Dr. Rose         NaN  2023-01-14 08:45
# 5        101    Alice   Cardiology  Dr. Smith      5000.0  2023-01-10 09:00

# %%
patients_drop=patients.drop(columns=['CheckInTime'])
patients_drop
# Out:
#    PatientID     Name   Department     Doctor  BillAmount  ReceptionistID
# 0        101    Alice   Cardiology  Dr. Smith      5000.0               1
# 1        102      Bob    Neurology   Dr. John         NaN               2
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0               1
# 3        104    David   Cardiology  Dr. Smith      6200.0               3
# 4        105      Eva  Dermatology   Dr. Rose         NaN               2
# 5        101    Alice   Cardiology  Dr. Smith      5000.0               1

# %% [raw]
# Use groupby to find total bill amount per department.

# %%
total_bill_per_department=selected_columns_billing.groupby('Department')['BillAmount'].sum().reset_index()
total_bill_per_department
# Out:
#     Department  BillAmount
# 0   Cardiology     16200.0
# 1  Dermatology         0.0
# 2    Neurology         0.0
# 3  Orthopedics      7500.0

# %% [raw]
# Use groupby to find total bill amount per department.

# %%
Remove_dup_patient=patients.drop_duplicates("PatientID")
Remove_dup_patient
# Out:
#    PatientID     Name   Department     Doctor  BillAmount  ReceptionistID  \
# 0        101    Alice   Cardiology  Dr. Smith      5000.0               1
# 1        102      Bob    Neurology   Dr. John         NaN               2
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0               1
# 3        104    David   Cardiology  Dr. Smith      6200.0               3
# 4        105      Eva  Dermatology   Dr. Rose         NaN               2
#
#         CheckInTime
# 0  2023-01-10 09:00
# 1  2023-01-11 10:30
# 2  2023-01-12 11:00
# 3  2023-01-13 12:00
# 4  2023-01-14 08:45

# %% [raw]
# Fill missing BillAmount values with the mean bill amount.

# %%
bill_amount=patients['BillAmount'].mean()
patients['BillAmount'] = patients['BillAmount'].fillna(bill_amount)
patients
# Out:
#    PatientID     Name   Department     Doctor  BillAmount  ReceptionistID  \
# 0        101    Alice   Cardiology  Dr. Smith      5000.0               1
# 1        102      Bob    Neurology   Dr. John      5925.0               2
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0               1
# 3        104    David   Cardiology  Dr. Smith      6200.0               3
# 4        105      Eva  Dermatology   Dr. Rose      5925.0               2
# 5        101    Alice   Cardiology  Dr. Smith      5000.0               1
#
#         CheckInTime
# 0  2023-01-10 09:00
# 1  2023-01-11 10:30
# 2  2023-01-12 11:00
# 3  2023-01-13 12:00
# 4  2023-01-14 08:45
# 5  2023-01-10 09:00

# %% [raw]
# Merge the billing dataset with patient dataset on PatientID

# %%
marge_patients=pd.merge(patients,selected_columns_billing,on='PatientID')
marge_patients
# Out:
#    PatientID     Name Department_x   Doctor_x  BillAmount_x  ReceptionistID  \
# 0        101    Alice   Cardiology  Dr. Smith        5000.0               1
# 1        101    Alice   Cardiology  Dr. Smith        5000.0               1
# 2        102      Bob    Neurology   Dr. John        5925.0               2
# 3        103  Charlie  Orthopedics    Dr. Lee        7500.0               1
# 4        104    David   Cardiology  Dr. Smith        6200.0               3
# 5        105      Eva  Dermatology   Dr. Rose        5925.0               2
# 6        101    Alice   Cardiology  Dr. Smith        5000.0               1
# 7        101    Alice   Cardiology  Dr. Smith        5000.0               1
#
#         CheckInTime Department_y   Doctor_y  BillAmount_y
# 0  2023-01-10 09:00   Cardiology  Dr. Smith        5000.0
# 1  2023-01-10 09:00   Cardiology  Dr. Smith        5000.0
# 2  2023-01-11 10:30    Neurology   Dr. John           NaN
# 3  2023-01-12 11:00  Orthopedics    Dr. Lee        7500.0
# 4  2023-01-13 12:00   Cardiology  Dr. Smith        6200.0
# 5  2023-01-14 08:45  Dermatology   Dr. Rose           NaN
# 6  2023-01-10 09:00   Cardiology  Dr. Smith        5000.0
# 7  2023-01-10 09:00   Cardiology  Dr. Smith        5000.0

# %% [raw]
# Concatenate an additional DataFrame that contains new patients for the current week (row-wise).

# %%
new_billing_columns=pd.DataFrame({
    'InsuranceCovered': [4000, 2000, 3500],  
    'FinalAmount': [1000, 1000, 500] 
})
new_billing_columns
# Out:
#    InsuranceCovered  FinalAmount
# 0              4000         1000
# 1              2000         1000
# 2              3500          500

# %% [raw]
# Concatenate new billing category columns like ['InsuranceCovered', 'FinalAmount'] (column-wise).

# %%
concat_columns=pd.concat([marge_patients,new_billing_columns],axis=1)
concat_columns
# Out:
#    PatientID     Name Department_x   Doctor_x  BillAmount_x  ReceptionistID  \
# 0        101    Alice   Cardiology  Dr. Smith        5000.0               1
# 1        101    Alice   Cardiology  Dr. Smith        5000.0               1
# 2        102      Bob    Neurology   Dr. John        5925.0               2
# 3        103  Charlie  Orthopedics    Dr. Lee        7500.0               1
# 4        104    David   Cardiology  Dr. Smith        6200.0               3
# 5        105      Eva  Dermatology   Dr. Rose        5925.0               2
# 6        101    Alice   Cardiology  Dr. Smith        5000.0               1
# 7        101    Alice   Cardiology  Dr. Smith        5000.0               1
#
#         CheckInTime Department_y   Doctor_y  BillAmount_y  InsuranceCovered  \
# 0  2023-01-10 09:00   Cardiology  Dr. Smith        5000.0            4000.0
# 1  2023-01-10 09:00   Cardiology  Dr. Smith        5000.0            2000.0
# 2  2023-01-11 10:30    Neurology   Dr. John           NaN            3500.0
# 3  2023-01-12 11:00  Orthopedics    Dr. Lee        7500.0               NaN
# 4  2023-01-13 12:00   Cardiology  Dr. Smith        6200.0               NaN
# 5  2023-01-14 08:45  Dermatology   Dr. Rose           NaN               NaN
# 6  2023-01-10 09:00   Cardiology  Dr. Smith        5000.0               NaN
# 7  2023-01-10 09:00   Cardiology  Dr. Smith        5000.0               NaN
#
#    FinalAmount
# 0       1000.0
# 1       1000.0
# 2        500.0
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN

# %%
marge_patients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PatientID       8 non-null      int64
#  1   Name            8 non-null      object
#  2   Department_x    8 non-null      object
#  3   Doctor_x        8 non-null      object
#  4   BillAmount_x    8 non-null      float64
#  5   ReceptionistID  8 non-null      int64
#  6   CheckInTime     8 non-null      object
#  7   Department_y    8 non-null      object
#  8   Doctor_y        8 non-null      object
#  9   BillAmount_y    6 non-null      float64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 772.0+ bytes
